# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("tech_layoffs2.csv")

# %%
df
# Out:
#             company total_layoffs impacted_workforce_percentage reported_date  \
# 0              C2FO            20                             2    2022-12-09
# 1          VideoAmp       Unclear                             2    2022-09-19
# 2          Amperity            13                             3    2022-08-20
# 3           Addepar            20                             3    2023-01-18
# 4    Thirty Madison            24                             3    2022-05-13
# ..              ...           ...                           ...           ...
# 484      Salesforce          9090                       Unclear    2023-01-04
# 485          Oracle       Unclear                       Unclear    2022-08-01
# 486      LivePerson       Unclear                       Unclear    2022-09-15
# 487          Skillz       Unclear                       Unclear    2022-08-29
# 488       Blueboard       Unclear                       Unclear    2022-11-03
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   company                        489 non-null    str
#  1   total_layoffs                  489 non-null    str
#  2   impacted_workforce_percentage  489 non-null    str
#  3   reported_date                  489 non-null    str
#  4   industry                       489 non-null    str
#  5   headquarter_location           489 non-null    str
#  6   sources                        489 non-null    str
#  7   status                         489 non-null    str
#  8   additional_notes               22 non-null     str
# dtypes: str(9)
# memory usage: 34.5 KB

# %%
df.shape
# Out:
# (489, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   company                        489 non-null    str
#  1   total_layoffs                  489 non-null    str
#  2   impacted_workforce_percentage  489 non-null    str
#  3   reported_date                  489 non-null    str
#  4   industry                       489 non-null    str
#  5   headquarter_location           489 non-null    str
#  6   sources                        489 non-null    str
#  7   status                         489 non-null    str
#  8   additional_notes               22 non-null     str
# dtypes: str(9)
# memory usage: 34.5 KB

# %%
df.describe()
# Out:
#                company total_layoffs impacted_workforce_percentage  \
# count              489           489                           489
# unique             477           150                            50
# top     Thirty Madison       Unclear                       Unclear
# freq                 2           182                           133
#
#        reported_date industry headquarter_location     sources   status  \
# count            489      489                  489         489      489
# unique           187      289                  134         221        2
# top       2023-01-11  Fintech        San Francisco  TechCrunch  Private
# freq              12       24                  136          52      370
#
#                                          additional_notes
# count                                                  22
# unique                                                 22
# top     Per Axios, 22 of the employees laid off were f...
# ...

# %%
df["total_layoffs"] = pd.to_numeric(df["total_layoffs"] , errors = 'coerce')

# %%
df["total_layoffs"]
# Out:
# 0        20.0
# 1         NaN
# 2        13.0
# 3        20.0
# 4        24.0
#         ...
# 484    9090.0
# 485       NaN
# 486       NaN
# 487       NaN
# 488       NaN
# Name: total_layoffs, Length: 489, dtype: float64

# %%
#df.groupby("company")["total_layoffs"].mean()

# %%
df["total_layoffs"].isna().sum()
# Out:
# np.int64(182)

# %%
df.head(10)
# Out:
#             company  total_layoffs impacted_workforce_percentage  \
# 0              C2FO           20.0                             2
# 1          VideoAmp            NaN                             2
# 2          Amperity           13.0                             3
# 3           Addepar           20.0                             3
# 4    Thirty Madison           24.0                             3
# 5          NextRoll            NaN                             3
# 6    Armis Security           25.0                             4
# 7           Foxtrot           26.0                             4
# 8  Headspace Health           50.0                             4
# 9          RealSelf           11.0                             5
#
#   reported_date                       industry headquarter_location  \
# 0    2022-12-09              Fintech, payments          Leawood, KS
# 1    2022-09-19          Advertising platforms          Los Angeles
# ...

# %%
df["impacted_workforce_percentage"] = pd.to_numeric(df["impacted_workforce_percentage"],errors = 'coerce')

# %%
df["impacted_workforce_percentage"].describe()
# Out:
# count    356.000000
# mean      23.876404
# std       24.809390
# min        1.000000
# 25%       10.000000
# 50%       15.000000
# 75%       25.000000
# max      100.000000
# Name: impacted_workforce_percentage, dtype: float64

# %%
df["impacted_workforce_percentage"].isna().sum()
# Out:
# np.int64(133)

# %%
df2 = df[df["impacted_workforce_percentage"] == 100]

# %%
df2
# Out:
#                 company  total_layoffs  impacted_workforce_percentage  \
# 234  Butler Hospitality         1000.0                          100.0
# 235           SummerBio          101.0                          100.0
# 236               Reali          140.0                          100.0
# 237                Fast          400.0                          100.0
# 238      Protocol Media           60.0                          100.0
# 239         WanderJaunt           85.0                          100.0
# 240                Wyre            NaN                          100.0
# 241             Lantern            NaN                          100.0
# 242   Lora DiCarlo Inc.            NaN                          100.0
# 243            Bitfront            NaN                          100.0
# 244              Assure            NaN                          100.0
# 245             GloriFi            NaN                          100.0
# ...

# %%
df.describe()
# Out:
#        total_layoffs  impacted_workforce_percentage
# count     307.000000                     356.000000
# mean      450.019544                      23.876404
# std      1652.123678                      24.809390
# min         5.000000                       1.000000
# 25%        44.000000                      10.000000
# 50%        95.000000                      15.000000
# 75%       200.000000                      25.000000
# max     18000.000000                     100.000000

# %%
df.loc[df["total_layoffs"].isna() , "total_layoffs"] = np.random.randint(df["total_layoffs"].min() , df["total_layoffs"].max(),df["total_layoffs"].isna().sum())

# %%
df.loc[df["impacted_workforce_percentage"].isna() , "impacted_workforce_percentage"] = np.random.randint(df["impacted_workforce_percentage"].min() , df["impacted_workforce_percentage"].max(),df["impacted_workforce_percentage"].isna().sum())

# %%
df["impacted_workforce_percentage"].isna().sum()
# Out:
# np.int64(0)

# %%
df["total_layoffs"].isna().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#             company  total_layoffs  impacted_workforce_percentage  \
# 0              C2FO           20.0                            2.0
# 1          VideoAmp         1505.0                            2.0
# 2          Amperity           13.0                            3.0
# 3           Addepar           20.0                            3.0
# 4    Thirty Madison           24.0                            3.0
# ..              ...            ...                            ...
# 484      Salesforce         9090.0                           47.0
# 485          Oracle         6149.0                           30.0
# 486      LivePerson         3568.0                           22.0
# 487          Skillz         3725.0                            5.0
# 488       Blueboard         5472.0                           48.0
#
#     reported_date                    industry headquarter_location  \
# 0      2022-12-09           Fintech, payments          Leawood, KS
# ...

# %%
df.isna().sum()
# Out:
# company                            0
# total_layoffs                      0
# impacted_workforce_percentage      0
# reported_date                      0
# industry                           0
# headquarter_location               0
# sources                            0
# status                             0
# additional_notes                 467
# dtype: int64

# %%
df.to_csv("tech_layoffs3.csv",index = False)

# %%
df["reported_date"] = pd.to_datetime(df["reported_date"])

# %%
df["reported_year"] = df["reported_date"].dt.year
